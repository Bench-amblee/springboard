# %% [markdown]
# # Part 2: SQLite + Python

# %%
import sqlite3
from sqlite3 import Error

def create_connection(db_file):
    conn = None
    try:
        conn = sqlite3.connect(db_file)
        print(sqlite3.version)
    except Error as e:
        print(e)
    return conn

def select_all_tasks(conn):
    cur = conn.cursor()
    query1 = """
        SELECT *
        FROM FACILITIES
        """    
    cur.execute(query1)
    rows = cur.fetchall()
    for row in rows:
        print(row)
        
def main():
    database = 'sqlite_db_pythonsqlite.db'
    conn = create_connection(database)
    with conn:
        print('2. Query all tasks')
        select_all_tasks(conn)

if __name__ == '__main__':
    main()
# Out:
# 2.6.0
# 2. Query all tasks
# (0, 'Tennis Court 1', 5, 25, 10000, 200)
# (1, 'Tennis Court 2', 5, 25, 8000, 200)
# (2, 'Badminton Court', 0, 15.5, 4000, 50)
# (3, 'Table Tennis', 0, 5, 320, 10)
# (4, 'Massage Room 1', 9.9, 80, 4000, 3000)
# (5, 'Massage Room 2', 9.9, 80, 4000, 3000)
# (6, 'Squash Court', 3.5, 17.5, 5000, 80)
# (7, 'Snooker Table', 0, 5, 450, 15)
# (8, 'Pool Table', 0, 5, 400, 15)

# %%
import sqlite3
from sqlite3 import Error
import pandas as pd

conn = sqlite3.connect("./sqlite_db_pythonsqlite.db")
cur = conn.cursor()

# %% [markdown]
# ### Produce a list of facilities with a total revenue less than 1000. The output of facility name and total revenue, sorted by revenue. Remember that there's a different cost for guests and members!

# %%
produce_list='''
SELECT facility_name, total_revenue from (
    SELECT f.name as facility_name,
    sum(CASE WHEN b.memid = 0 THEN f.guestcost*b.slots
        ELSE f.membercost*b.slots
        END) AS total_revenue
    FROM Facilities as f
    INNER JOIN Bookings as b
    USING (facid)
    GROUP BY f.name
    ) AS sample
WHERE total_revenue > 1000
ORDER BY total_revenue;
'''

pd.read_sql(produce_list,conn)
# Out:
#      facility_name  total_revenue
# 0  Badminton Court         1906.5
# 1     Squash Court        13468.0
# 2   Tennis Court 1        13860.0
# 3   Tennis Court 2        14310.0
# 4   Massage Room 2        14454.6
# 5   Massage Room 1        50351.6

# %% [markdown]
# ### Produce a report of members and who recommended them in alphabetic, surname, firstname order

# %%
produce_report='''
SELECT m.memid, m.recommendedby, m.firstname, m.surname, r.firstname AS rec_firstname, r.surname AS rec_surname
FROM Members AS m
LEFT OUTER JOIN Members as r
ON r.memid = m.recommendedby
ORDER BY m.firstname, m.surname;
'''

pd.read_sql(produce_report,conn)
# Out:
#     memid recommendedby  firstname            surname rec_firstname  \
# 0      21             1       Anna          Mackenzie        Darren
# 1      12             9       Anne              Baker        Ponder
# 2       6                   Burton              Tracy          None
# 3      10             1    Charles               Owen        Darren
# 4       1                   Darren              Smith          None
# 5      37                   Darren              Smith          None
# 6      28                    David            Farrell          None
# 7      11             4      David              Jones        Janice
# 8      17            13      David             Pinker        Jemima
# 9      26            11    Douglas              Jones         David
# 10     36             2      Erica            Crumpet         Tracy
# 11     15             9   Florence              Bader        Ponder
# 12      0                    GUEST              GUEST          None
# 13      5             1     Gerald            Butters        Darren
# 14     27            20  Henrietta             Rumney       Matthew
# 15     29             2      Henry  Worthington-Smyth         Tracy
# 16     33                 Hyacinth         Tupperware          None
# 17     14             1       Jack              Smith        Darren
# 18      4             1     Janice           Joplette        Darren
# 19     13                   Jemima            Farrell          None
# 20     22            16       Joan             Coplin       Timothy
# 21     35            30       John               Hunt     Millicent
# 22     20             5    Matthew            Genting        Gerald
# 23     30             2  Millicent            Purview         Tracy
# 24      7             4      Nancy               Dare        Janice
# 25      9             6     Ponder           Stibbons        Burton
# 26     24            15  Ramnaresh             Sarwin      Florence
# 27      8             3        Tim             Boothe           Tim
# 28      3                      Tim             Rownam          None
# 29     16            13    Timothy              Baker        Jemima
# 30      2                    Tracy              Smith          None
#
#    rec_surname
# 0        Smith
# 1     Stibbons
# 2         None
# 3        Smith
# 4         None
# 5         None
# 6         None
# 7     Joplette
# 8      Farrell
# 9        Jones
# 10       Smith
# 11    Stibbons
# 12        None
# 13       Smith
# 14     Genting
# 15       Smith
# 16        None
# 17       Smith
# 18       Smith
# 19        None
# 20       Baker
# 21     Purview
# 22     Butters
# 23       Smith
# 24    Joplette
# 25       Tracy
# 26       Bader
# 27      Rownam
# 28        None
# 29     Farrell
# 30        None

# %% [markdown]
# ### Find the facilities with their usage by member, but not guests

# %%
find_facilities = '''
SELECT facility_name, member_name, ROUND(sum_slots,1) AS monthly_usage from (
    SELECT f.name AS facility_name, 
    m.firstname || m.surname AS member_name,
    SUM(slots) AS sum_slots
    FROM Members AS m
    INNER JOIN Bookings as b
    USING (memid)
    INNER JOIN Facilities as f
    USING (facid)
    WHERE b.memid != 0
    GROUP BY f.facid, member_name
    ) as sub_q1
ORDER BY facility_name, member_name DESC
'''

pd.read_sql(find_facilities,conn)
# Out:
#        facility_name      member_name  monthly_usage
# 0    Badminton Court       TracySmith          102.0
# 1    Badminton Court     TimothyBaker           21.0
# 2    Badminton Court        TimRownam           12.0
# 3    Badminton Court        TimBoothe           36.0
# 4    Badminton Court  RamnareshSarwin           21.0
# ..               ...              ...            ...
# 197   Tennis Court 2     DavidFarrell            3.0
# 198   Tennis Court 2      DarrenSmith           57.0
# 199   Tennis Court 2      CharlesOwen          141.0
# 200   Tennis Court 2      BurtonTracy            9.0
# 201   Tennis Court 2        AnneBaker          114.0
#
# [202 rows x 3 columns]

# %% [markdown]
# ### Find the facilities usage by month, but not guests

# %%
find_facilities2='''
SELECT strftime('%m', starttime) AS month_2012, f.name AS facility_name, COUNT(*) AS monthly_usage
FROM Bookings AS b
    INNER JOIN Facilities AS f
    USING (facid)
    WHERE b.memid != 0
    GROUP BY month_2012, name
'''

pd.read_sql(find_facilities2,conn)
# Out:
#    month_2012    facility_name  monthly_usage
# 0          07  Badminton Court             51
# 1          07   Massage Room 1             77
# 2          07   Massage Room 2              4
# 3          07       Pool Table            103
# 4          07    Snooker Table             68
# 5          07     Squash Court             23
# 6          07     Table Tennis             48
# 7          07   Tennis Court 1             65
# 8          07   Tennis Court 2             41
# 9          08  Badminton Court            132
# 10         08   Massage Room 1            153
# 11         08   Massage Room 2              9
# 12         08       Pool Table            272
# 13         08    Snooker Table            154
# 14         08     Squash Court             85
# 15         08     Table Tennis            143
# 16         08   Tennis Court 1            111
# 17         08   Tennis Court 2            109
# 18         09  Badminton Court            161
# 19         09   Massage Room 1            191
# 20         09   Massage Room 2             14
# 21         09       Pool Table            408
# 22         09    Snooker Table            199
# 23         09     Squash Court             87
# 24         09     Table Tennis            194
# 25         09   Tennis Court 1            132
# 26         09   Tennis Court 2            126
